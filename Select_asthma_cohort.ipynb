# %%
from pyspark.sql import SparkSession

# %%
print('hello')
# Out:
# hello

# %%
sparkSession = SparkSession.builder.appName("example-pyspark-read-and-write").getOrCreate()

# %%
df_load = sparkSession.read.csv('hdfs:///data/unstructured/integrated/gene_e/ukbiobank/analysis-files/UKB9888.ALL.20180530.txt',header=True,inferSchema=True,sep='\t')

# %%
#print df_load.count()

# %%
df_asthma=df_load.filter(df_load.asthma==1.0)

# %%
print df_asthma.count()
# Out:
# 61171

# %%
print df_asthma.select('asthma').show(5)
# Out:
# +------+
# |asthma|
# +------+
# |     1|
# |     1|
# |     1|
# |     1|
# |     1|
# +------+
# only showing top 5 rows
#
# None

# %%
df_asthma.limit(5000).toPandas().to_csv("ukbb_asthma_sample_5k_new.csv",sep='\t')

# %%
#use .limit() to select rows

# %%
df_asthma
# Out:
# DataFrame[FID: int, IID: int, RGC_ID: string, random_normal: string, random_binary: string, sex: string, chip: string, PC1: string, PC2: string, PC3: string, PC4: string, PC5: string, PC6: string, PC7: string, PC8: string, PC9: string, PC10: string, PC11: string, PC12: string, PC13: string, PC14: string, PC15: string, PC16: string, PC17: string, PC18: string, PC19: string, PC20: string, PC21: string, PC22: string, PC23: string, PC24: string, PC25: string, PC26: string, PC27: string, PC28: string, PC29: string, PC30: string, PC31: string, PC32: string, PC33: string, PC34: string, PC35: string, PC36: string, PC37: string, PC38: string, PC39: string, PC40: string, age: string, BMI: string, asthma: string, f_20006_0_0_f_QUANT_Interpolated_Year_when_cancer_first_diagnosed: string, f_20008_0_0_f_QUANT_Interpolated_Year_when_non_cancer_illness_first_diagnosed: string, f_20010_0_0_f_QUANT_Interpolated_Year_when_operation_took_place: string, f_20018_0_0_f_QUANT_Prospective_memory_result: string, f_22508_0_0_f_QUANT_Amount_of_tobacco_currently_smoked: string, f_1160_0_0_f_QUANT_Sleep_duration: string, f_1269_0_0_f_QUANT_Exposure_to_tobacco_smoke_at_home: string, f_1279_0_0_f_QUANT_Exposure_to_tobacco_smoke_outside_home: string, f_1807_0_0_f_QUANT_Father_s_age_at_death: string, f_2714_0_0_f_QUANT_Age_when_periods_started_menarche: string, f_2867_0_0_f_QUANT_Age_started_smoking_in_former_smokers: string, f_2966_0_0_f_QUANT_Age_high_blood_pressure_diagnosed: string, f_2976_0_0_f_QUANT_Age_diabetes_diagnosed: string, f_3436_0_0_f_QUANT_Age_started_smoking_in_current_smokers: string, f_3526_0_0_f_QUANT_Mother_s_age_at_death: string, f_3536_0_0_f_QUANT_Age_started_hormone_replacement_therapy_HRT: string, f_3581_0_0_f_QUANT_Age_at_menopause_last_menstrual_period: string, f_3627_0_0_f_QUANT_Age_angina_diagnosed: string, f_3761_0_0_f_QUANT_Age_hay_fever_rhinitis_or_eczema_diagnosed: string, f_3786_0_0_f_QUANT_Age_asthma_diagnosed: string, f_3829_0_0_f_QUANT_Number_of_stillbirths: string, f_3839_0_0_f_QUANT_Number_of_spontaneous_miscarriages: string, f_3882_0_0_f_QUANT_Age_at_bilateral_oophorectomy_both_ovaries_removed: string, f_3894_0_0_f_QUANT_Age_heart_attack_diagnosed: string, f_3992_0_0_f_QUANT_Age_emphysema_chronic_bronchitis_diagnosed: string, f_4012_0_0_f_QUANT_Age_deep_vein_thrombosis_DVT_blood_clot_in_leg_diagnosed: string, f_4022_0_0_f_QUANT_Age_pulmonary_embolism_blood_clot_in_lung_diagnosed: string, f_4056_0_0_f_QUANT_Age_stroke_diagnosed: string, f_5430_0_0_f_QUANT_Age_when_loss_of_vision_due_to_injury_or_trauma_diagnosed: string, f_4609_0_0_f_QUANT_Longest_period_of_depression: string, f_4620_0_0_f_QUANT_Number_of_depression_episodes: string, f_4689_0_0_f_QUANT_Age_glaucoma_diagnosed: string, f_4700_0_0_f_QUANT_Age_cataract_diagnosed: string, f_5375_0_0_f_QUANT_Longest_period_of_unenthusiasm_disinterest: string, f_5386_0_0_f_QUANT_Number_of_unenthusiastic_disinterested_episodes: string, f_6194_0_0_f_QUANT_Age_stopped_smoking_cigarettes_current_cigar_pipe_or_previous_cigarette_smoker: string, f_816_0_0_f_QUANT_Job_involves_heavy_manual_or_physical_work: string, f_1170_0_0_f_QUANT_Getting_up_in_morning: string, f_1180_0_0_f_QUANT_Morning_evening_person_chronotype: string, f_1190_0_0_f_QUANT_Nap_during_day: string, f_1200_0_0_f_QUANT_Sleeplessness_insomnia: string, f_1220_0_0_f_QUANT_Daytime_dozing_sleeping_narcolepsy: string, f_1249_0_0_f_QUANT_Past_tobacco_smoking: string, f_2887_0_0_f_QUANT_Number_of_cigarettes_previously_smoked_daily: string, f_6183_0_0_f_QUANT_Number_of_cigarettes_previously_smoked_daily_current_cigar_pipe_smokers: string, f_3456_0_0_f_QUANT_Number_of_cigarettes_currently_smoked_daily_current_cigarette_smokers: string, f_3466_0_0_f_QUANT_Time_from_waking_to_first_cigarette: string, f_1558_0_0_f_QUANT_Alcohol_intake_frequency: string, f_1757_0_0_f_QUANT_Facial_ageing: string, f_4526_0_0_f_QUANT_Happiness: string, f_4548_0_0_f_QUANT_Health_satisfaction: string, f_4537_0_0_f_QUANT_Work_job_satisfaction: string, f_2 ...
