# %%
import pandas as pd 
import numpy as np
# %matplotlib inline
from matplotlib import rc
rc('font', **{'family':'sans-serif','sans-serif':['Helvetica']})
#rc('text', usetex=False)
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']=(12,6)

# %%
#Read in 5K sample
asthma_df=pd.read_csv("ukbb_asthma_sample_5k_new.csv",sep='\t')

# %% [markdown]
# ## Read in the top uncorrelated pairs File, and filter the data

# %%
top_uncorrelated_df=pd.read_csv('uncorrelated_pairs_final.csv',header=None)
top_uncorrelated_df=top_uncorrelated_df.rename(columns={0:'Uncorrelated Rank',1:'Feature 1',2:'Feature 2',3:'Correlation'})

# %%
top_uncorrelated_df.head()
# Out:
#    Uncorrelated Rank                                          Feature 1  \
# 0                  4  f_20151_0_0_f_QUANT_Forced_vital_capacity_FVC_...
# 1                  8         specialRequest_QUANT_FEV1_ever_smoked_only
# 2                 10   f_30050_0_0_f_QUANT_Mean_corpuscular_haemoglobin
# 3                 35              specialRequest_QUANT_FEV1_pred_strict
# 4                 46           f_30220_0_0_f_QUANT_Basophill_percentage
#
#                                            Feature 2  Correlation
# 0           f_30220_0_0_f_QUANT_Basophill_percentage     0.000004
# 1  f_23099_0_0_f_QUANT_Body_fat_percentage_residu...     0.000010
# 2              specialRequest_QUANT_FEV1_pred_strict     0.000014
# 3  f_4080_0_f_QUANT_systolic_blood_pressure_mean_...     0.000030
# 4  specialRequest_QUANT_FEV1_ever_smoked_only_str...     0.000040

# %%
# Select Columns
cols=np.append(top_uncorrelated_df['Feature 1'].unique(),top_uncorrelated_df['Feature 2'].unique())
cols=np.unique(cols)
asthma_df_uncorrelated=asthma_df[cols]

# %%
asthma_df_uncorrelated_info = asthma_df_uncorrelated.describe()
print(asthma_df_uncorrelated_info.T)
asthma_df_uncorrelated_info.T.to_csv('uncorrelated pairs info.csv')
# Out:
#                                                      count       mean  \
# f_20107_20110_code3_QUANT_Lung_cancer_residuali...  5000.0   0.023039
# f_20151_0_0_f_QUANT_Forced_vital_capacity_FVC_B...  3783.0   3.610999
# f_23099_0_0_f_QUANT_Body_fat_percentage_residua...  4909.0   0.156657
# f_30030_0_0_f_QUANT_Haematocrit_percentage          4861.0  41.075703
# f_30050_0_0_f_QUANT_Mean_corpuscular_haemoglobin    4861.0  31.488618
# f_30060_0_0_f_QUANT_Mean_corpuscular_haemoglobi...  4861.0  34.508731
# f_30060_0_0_f_QUANT_Mean_corpuscular_haemoglobi...  4861.0  -0.048964
# f_30210_0_0_f_QUANT_Eosinophill_percentage_resi...  4855.0   0.329780
# f_30220_0_0_f_QUANT_Basophill_percentage            4855.0   0.576315
# f_30270_0_0_f_QUANT_Mean_sphered_cell_volume        4790.0  82.743031
# f_30270_0_0_f_QUANT_Mean_sphered_cell_volume_re...  4790.0  -0.021347
# f_3063_0_f_QUANT_FEV1_maximumValue_residualized...  3822.0  -0.416744
# f_34_0_0_f_QUANT_Year_of_birth_residualizedRelated  5000.0   0.001463
# f_4080_0_f_QUANT_systolic_blood_pressure_mean_r...  4734.0  -0.000696
# specialRequest_QUANT_FEV1_FVC_ratio_ever_smoked...  2345.0   0.717010
# specialRequest_QUANT_FEV1_FVC_ratio_ever_smoked...  1912.0   0.718443
# specialRequest_QUANT_FEV1_FVC_ratio_strict          3094.0   0.723127
# specialRequest_QUANT_FEV1_ever_smoked_only          2345.0   2.609527
# specialRequest_QUANT_FEV1_ever_smoked_only_stri...  1912.0  -0.397560
# specialRequest_QUANT_FEV1_percent_pred_residual...  3814.0  -0.427377
# specialRequest_QUANT_FEV1_percent_pred_strict       3094.0  89.204376
# specialRequest_QUANT_FEV1_pred_strict               3094.0   2.895035
# specialRequest_QUANT_pack_years                     1534.0  25.243628
#
#                                                           std        min  \
# f_20107_20110_code3_QUANT_Lung_cancer_residuali...   1.038823  -3.797089
# f_20151_0_0_f_QUANT_Forced_vital_capacity_FVC_B...   0.986497   0.740000
# f_23099_0_0_f_QUANT_Body_fat_percentage_residua...   1.022882  -3.245504
# f_30030_0_0_f_QUANT_Haematocrit_percentage           3.512944  15.760000
# f_30050_0_0_f_QUANT_Mean_corpuscular_haemoglobin     2.019824  18.910000
# f_30060_0_0_f_QUANT_Mean_corpuscular_haemoglobi...   1.346397  30.760000
# f_30060_0_0_f_QUANT_Mean_corpuscular_haemoglobi...   1.011678  -3.280003
# f_30210_0_0_f_QUANT_Eosinophill_percentage_resi...   1.055838  -3.492391
# f_30220_0_0_f_QUANT_Basophill_percentage             0.613692   0.000000
# f_30270_0_0_f_QUANT_Mean_sphered_cell_volume         5.195209  44.500000
# f_30270_0_0_f_QUANT_Mean_sphered_cell_volume_re...   0.988463  -4.432896
# f_3063_0_f_QUANT_FEV1_maximumValue_residualized...   1.004219  -3.636833
# f_34_0_0_f_QUANT_Year_of_birth_residualizedRelated   1.004337  -3.749113
# f_4080_0_f_QUANT_systolic_blood_pressure_mean_r...   0.965823  -4.577357
# specialRequest_QUANT_FEV1_FVC_ratio_ever_smoked...   0.085127   0.166667
# specialRequest_QUANT_FEV1_FVC_ratio_ever_smoked...   0.083590   0.333333
# specialRequest_QUANT_FEV1_FVC_ratio_strict           0.081555   0.333333
# specialRequest_QUANT_FEV1_ever_smoked_only           0.777211   0.410000
# specialRequest_QUANT_FEV1_ever_smoked_only_stri...   1.039139  -3.840057
# specialRequest_QUANT_FEV1_percent_pred_residual...   1.008168  -3.573208
# specialRequest_QUANT_FEV1_percent_pred_strict       18.079906  21.328336
# specialRequest_QUANT_FEV1_pred_strict                0.586652   1.652294
# specialRequest_QUANT_pack_years                     20.854579   0.000000
#
#                                                           25%        50%  \
# f_20107_20110_code3_QUANT_Lung_cancer_residuali...  -0.698988   0.061353
# f_20151_0_0_f_QUANT_Forced_vital_capacity_FVC_B...   2.910000   3.490000
# f_23099_0_0_f_QUANT_Body_fat_percentage_residua...  -0.545986   0.164217
# f_30030_0_0_f_QUANT_Haematocrit_percentage          38.720000  41.000000
# f_30050_0_0_f_QUANT_Mean_corpuscular_haemoglobin    30.500000  31.500000
# f_30060_0_0_f_QUANT_Mean_corpuscular_haemoglobi...  33.850000  34.410000
# f_30060_0_0_f_QUANT_Mean_corpuscular_haemoglobi...  -0.729150  -0.057442
# f_30210_0_0_f_QUANT_Eosinophill_percentage_resi...  -0.386319   0.366308
# f_30220_0_0_f_QUANT_Basophill_percentage             0.300000   0.430000
# f_30270_0_0_f_QUANT_Mean_sphered_cell_volume        79.290000  82.590000
# f_30270_0_0_f_QUANT_Mean_sphered_cell_volume_re...  -0.697352  -0.022441
# f_3063_0_f_QUANT_FEV1_maximumValue_residualized...  -1.117720  -0.431247
# f_34_0_0_f_QUANT_Year_of_birth_residualizedRelated  -0.651339   0.029583
# f_4080_0_f_QUANT_systolic_blood_pressure_mean_r...  -0.646386   0.003616
# specialRequest_QUANT_FEV1_FVC_ratio_ever_smoked...   0.676056   0.732955
# specialRequest_QUANT_FEV1_FVC_ratio_ever_smoked...   0.679255   0.734105
# specialRequest_QUANT_FEV1_FVC_ratio_strict           0.683967   0.737090
# specialRequest_QUANT_FEV1_ever_smoked_only           2.090000   2.560000
# specialRequest_QUANT_FEV1_ever_smoked_only_stri...  -1.106026  -0.411317
# specialRequest_QUANT_FEV1_percent_pred_residual...  -1.110557  -0.460074
# specialRequest_QUANT_FEV1_percent_pred_strict       79.057166  90.695413
# specialRequest_QUANT_FEV1_pred_strict                2.411578   2.833894
# specialRequest_QUANT_pack_years                     10.500000  20.000000
#
#                                                            75%         max
# f_20107_20110_code3_QUANT_Lung_cancer_residuali...    0.712386    3.870315
# f_20151_0_0_f_QUANT_Forced_vital_capacity_FVC_B...    4.220000    8.150000
# f_23099_0_0_f_QUANT_Body_fat_percentage_residua...    0.842216    3.767474
# f_30030_0_0_f_QUANT_Haematocrit_percentage           43.400000   54.600000
# f_30050_0_0_f_QUANT_Mean_corpuscular_haemoglobin     32.500000   87.510000
# f_30060_0_0_f_QUANT_Mean_corpuscular_haemoglobi...   35.090000   87.640000
# f_30060_0_0_f_QUANT_Mean_corpuscular_haemoglobi...    0.629899    4.436440
# f_30210_0_0_f_QUANT_Eosinophill_percentage_resi...    1.064519    3.689755
# f_30220_0_0_f_QUANT_Basophill_percentage              0.690000   17.400000
# f_30270_0_0_f_QUANT_Mean_sphered_cell_volume         85.927500  128.880000
# f_30270_0_0_f_QUANT_Mean_sphered_cell_volume_re...    0.646565    3.977199
# f_3063_0_f_QUANT_FEV1_maximumValue_residualized...    0.262702    3.355297
# f_34_0_0_f_QUANT_Year_of_birth_residualizedRelated    0.671510    3.498403
# f_4080_0_f_QUANT_systolic_blood_pressure_mean_r...    0.645852    3.072365
# specialRequest_QUANT_FEV1_FVC_ratio_ever_smoked...    0.776025    0.900302
# specialRequest_QUANT_FEV1_FVC_ratio_ever_smoked...    0.776055    0.900302
# specialRequest_QUANT_FEV1_FVC_ratio_strict            0.780639    0.900302
# specialRequest_QUANT_FEV1_ever_smoked_only            3.100000    5.500000
# specialRequest_QUANT_FEV1_ever_smoked_only_stri...    0.320221    3.447488
# specialRequest_QUANT_FEV1_percent_pred_residual...    0.249689    3.230852
# specialRequest_QUANT_FEV1_percent_pred_strict       101.110780  172.489537
# specialRequest_QUANT_FEV1_pred_strict                 3.355497    4.523667
# specialRequest_QUANT_pack_years                      34.500000  198.000000

# %% [markdown]
# ## Task #2) Get the Mean and Standard Deviations for all the uncorrelated variables.
#
# Hints:
# * The describe function is your friend
# * the asthma_df_uncorrelated data frame is already filtered for the uncorrelated variables
# * Print this table to the screen, and save it as a CSV table with the to_csv() function

# %% [markdown]
# # Task #3) Table of most correlated variables along with correlation values
#
# This task is actually complete with your manually created CSV files of the most important correlated and uncorrelated variables

# %% [markdown]
# ## Task #4) Box plots and scatter plots of final correlated variable list
#
# Below, I plot just one of the variables and save it as a file. Your task: make a for loop that looks through all the variable pairs, make the plots, and save the output.

# %%
for i in range(0,len(top_uncorrelated_df)):
    #print(i)
    boxplot=asthma_df_uncorrelated.boxplot(column=[top_uncorrelated_df['Feature 1'][i],top_uncorrelated_df['Feature 2'][i]],rot=90)
    scatterplot=asthma_df_uncorrelated.plot.scatter(x=top_uncorrelated_df['Feature 1'][i],y=top_uncorrelated_df['Feature 2'][i])
    plt.show(boxplot)
    boxplot.get_figure().savefig('boxplot_uncorrelated_'+str(top_uncorrelated_df['Uncorrelated Rank'][i])+'.png',bbox_inches='tight')
    plt.show(scatterplot)
    scatterplot.get_figure().savefig('scatterplot_uncorrelated_'+str(top_uncorrelated_df['Uncorrelated Rank'][i])+'.png',bbox_inches='tight')



#for i in xrange(2,4):
#    boxplot=asthma_df.boxplot(column=[corr_var_df['Variable1'][i],corr_var_df['Variable2'][i]])
#    scatterplot=asthma_df.plot.scatter(x=corr_var_df['Variable1'][i],y=corr_var_df['Variable2'][i])
#    plt.show(boxplot)
#    plt.show(scatterplot)

# %%
#for i in asthma_df_uncorrelated
i=0
boxplot=asthma_df_uncorrelated.boxplot(column=[top_uncorrelated_df['Feature 1'][i],top_uncorrelated_df['Feature 2'][i]],rot=90)
scatterplot=asthma_df_uncorrelated.plot.scatter(x=top_uncorrelated_df['Feature 1'][i],y=top_uncorrelated_df['Feature 2'][i])
plt.show(boxplot)
boxplot.get_figure().savefig('boxplot_uncorrelated_'+str(top_uncorrelated_df['Uncorrelated Rank'][i])+'.png',bbox_inches='tight')
plt.show(scatterplot)
scatterplot.get_figure().savefig('scatterplot_uncorrelated_'+str(top_uncorrelated_df['Uncorrelated Rank'][i])+'.png',bbox_inches='tight')
# Out:
# /opt/wakari/anaconda/envs/default/lib/python2.7/site-packages/matplotlib/font_manager.py:1328: UserWarning: findfont: Font family [u'sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ## Repeat the above, but for the top Correlated Variables

# %%
top_correlated_df=pd.read_csv('correlated_pairs_final_.csv',header=None)
top_correlated_df=top_correlated_df.rename(columns={0:'Correlated Rank',1:'Feature 1',2:'Feature 2',3:'Correlation'})

# %%
top_correlated_df.head()
# Out:
#    Correlated Rank                                          Feature 1  \
# 0                2      f_30020_0_0_f_QUANT_Haemoglobin_concentration
# 1                6        f_30040_0_0_f_QUANT_Mean_corpuscular_volume
# 2               40  f_30010_0_0_f_QUANT_Red_blood_cell_erythrocyte...
# 3               42   f_30050_0_0_f_QUANT_Mean_corpuscular_haemoglobin
# 4              181                 f_30080_0_0_f_QUANT_Platelet_count
#
#                                            Feature 2  Correlation
# 0         f_30030_0_0_f_QUANT_Haematocrit_percentage     0.989429
# 1   f_30050_0_0_f_QUANT_Mean_corpuscular_haemoglobin     0.985624
# 2         f_30030_0_0_f_QUANT_Haematocrit_percentage     0.973988
# 3  f_30060_0_0_f_QUANT_Mean_corpuscular_haemoglob...     0.971441
# 4                  f_30090_0_0_f_QUANT_Platelet_crit     0.927603

# %%
# Select Columns
cols=np.append(top_correlated_df['Feature 1'].unique(),top_correlated_df['Feature 2'].unique())
cols=np.unique(cols)
asthma_df_correlated=asthma_df[cols]

# %%
asthma_df_correlated_info = asthma_df_correlated.describe()
print(asthma_df_correlated_info.T)
asthma_df_correlated_info.T.to_csv('correlated pairs info.csv')
# Out:
#                                                      count        mean  \
# f_100003_0_0_f_QUANT_Protein                         706.0   82.017252
# f_100006_0_0_f_QUANT_Saturated_fat                   706.0   29.739193
# f_100008_0_0_f_QUANT_Total_sugars                    706.0  122.442450
# f_20107_20110_code11_QUANT_Parkinson_s_disease_...  5000.0    0.046047
# f_21003_0_0_f_QUANT_Age_when_attended_assessmen...  5000.0    0.038502
# f_30010_0_0_f_QUANT_Red_blood_cell_erythrocyte_...  4861.0    4.509217
# f_30020_0_0_f_QUANT_Haemoglobin_concentration       4861.0   14.166305
# f_30020_0_0_f_QUANT_Haemoglobin_concentration_r...  4861.0    0.010621
# f_30030_0_0_f_QUANT_Haematocrit_percentage          4861.0   41.075703
# f_30030_0_0_f_QUANT_Haematocrit_percentage_resi...  4861.0    0.027821
# f_30040_0_0_f_QUANT_Mean_corpuscular_volume         4861.0   91.240938
# f_30050_0_0_f_QUANT_Mean_corpuscular_haemoglobin    4861.0   31.488618
# f_30060_0_0_f_QUANT_Mean_corpuscular_haemoglobi...  4861.0   34.508731
# f_30070_0_0_f_QUANT_Red_blood_cell_erythrocyte_...  4861.0   13.528009
# f_30080_0_0_f_QUANT_Platelet_count                  4861.0  261.170335
# f_30090_0_0_f_QUANT_Platelet_crit                   4861.0    0.239087
# f_30110_0_0_f_QUANT_Platelet_distribution_width     4861.0   16.472409
# f_30200_0_0_f_QUANT_Neutrophill_percentage          4855.0   61.387522
# f_30260_0_0_f_QUANT_Mean_reticulocyte_volume        4790.0  105.652551
# f_30270_0_0_f_QUANT_Mean_sphered_cell_volume        4790.0   82.743031
# f_47_f_QUANT_grip_strength_maximumValue             4971.0   30.900624
# f_50_0_0_f_QUANT_Standing_height                    4979.0  167.912432
# specialRequest_QUANT_FEV1_pred                      4979.0    2.904001
# specialRequest_QUANT_age_stopped_smoking            1766.0   43.955266
# specialRequest_QUANT_pack_years                     1534.0   25.243628
#
#                                                           std         min  \
# f_100003_0_0_f_QUANT_Protein                        31.534247    7.540000
# f_100006_0_0_f_QUANT_Saturated_fat                  14.881890    2.840000
# f_100008_0_0_f_QUANT_Total_sugars                   60.430143    8.020000
# f_20107_20110_code11_QUANT_Parkinson_s_disease_...   1.017337   -3.066608
# f_21003_0_0_f_QUANT_Age_when_attended_assessmen...   1.021029   -2.430671
# f_30010_0_0_f_QUANT_Red_blood_cell_erythrocyte_...   0.408440    1.578000
# f_30020_0_0_f_QUANT_Haemoglobin_concentration        1.220332    9.100000
# f_30020_0_0_f_QUANT_Haemoglobin_concentration_r...   1.015498   -3.380022
# f_30030_0_0_f_QUANT_Haematocrit_percentage           3.512944   15.760000
# f_30030_0_0_f_QUANT_Haematocrit_percentage_resi...   1.014679   -3.857993
# f_30040_0_0_f_QUANT_Mean_corpuscular_volume          4.413203   61.000000
# f_30050_0_0_f_QUANT_Mean_corpuscular_haemoglobin     2.019824   18.910000
# f_30060_0_0_f_QUANT_Mean_corpuscular_haemoglobi...   1.346397   30.760000
# f_30070_0_0_f_QUANT_Red_blood_cell_erythrocyte_...   1.063720   11.290000
# f_30080_0_0_f_QUANT_Platelet_count                  64.431466   14.500000
# f_30090_0_0_f_QUANT_Platelet_crit                    0.052841    0.014000
# f_30110_0_0_f_QUANT_Platelet_distribution_width      0.506511   15.200000
# f_30200_0_0_f_QUANT_Neutrophill_percentage           8.666924    1.490000
# f_30260_0_0_f_QUANT_Mean_reticulocyte_volume         7.875996   58.810000
# f_30270_0_0_f_QUANT_Mean_sphered_cell_volume         5.195209   44.500000
# f_47_f_QUANT_grip_strength_maximumValue             11.481881    0.000000
# f_50_0_0_f_QUANT_Standing_height                     9.352997  100.000000
# specialRequest_QUANT_FEV1_pred                       0.597725    0.285859
# specialRequest_QUANT_age_stopped_smoking            12.673174   14.000000
# specialRequest_QUANT_pack_years                     20.854579    0.000000
#
#                                                            25%         50%  \
# f_100003_0_0_f_QUANT_Protein                         61.447500   78.720000
# f_100006_0_0_f_QUANT_Saturated_fat                   19.505000   27.325000
# f_100008_0_0_f_QUANT_Total_sugars                    77.857500  114.220000
# f_20107_20110_code11_QUANT_Parkinson_s_disease_...   -0.676164    0.064283
# f_21003_0_0_f_QUANT_Age_when_attended_assessmen...   -0.640628   -0.023428
# f_30010_0_0_f_QUANT_Red_blood_cell_erythrocyte_...    4.235000    4.494000
# f_30020_0_0_f_QUANT_Haemoglobin_concentration        13.370000   14.140000
# f_30020_0_0_f_QUANT_Haemoglobin_concentration_r...   -0.688969    0.025495
# f_30030_0_0_f_QUANT_Haematocrit_percentage           38.720000   41.000000
# f_30030_0_0_f_QUANT_Haematocrit_percentage_resi...   -0.665530    0.029305
# f_30040_0_0_f_QUANT_Mean_corpuscular_volume          88.590000   91.220000
# f_30050_0_0_f_QUANT_Mean_corpuscular_haemoglobin     30.500000   31.500000
# f_30060_0_0_f_QUANT_Mean_corpuscular_haemoglobi...   33.850000   34.410000
# f_30070_0_0_f_QUANT_Red_blood_cell_erythrocyte_...   12.900000   13.370000
# f_30080_0_0_f_QUANT_Platelet_count                  219.000000  256.000000
# f_30090_0_0_f_QUANT_Platelet_crit                     0.206000    0.234000
# f_30110_0_0_f_QUANT_Platelet_distribution_width      16.100000   16.410000
# f_30200_0_0_f_QUANT_Neutrophill_percentage           56.200000   61.600000
# f_30260_0_0_f_QUANT_Mean_reticulocyte_volume        101.257500  105.665000
# f_30270_0_0_f_QUANT_Mean_sphered_cell_volume         79.290000   82.590000
# f_47_f_QUANT_grip_strength_maximumValue              22.000000   30.000000
# f_50_0_0_f_QUANT_Standing_height                    161.000000  167.000000
# specialRequest_QUANT_FEV1_pred                        2.404863    2.855139
# specialRequest_QUANT_age_stopped_smoking             34.000000   44.000000
# specialRequest_QUANT_pack_years                      10.500000   20.000000
#
#                                                            75%          max
# f_100003_0_0_f_QUANT_Protein                         97.662500   249.210000
# f_100006_0_0_f_QUANT_Saturated_fat                   38.207500   104.320000
# f_100008_0_0_f_QUANT_Total_sugars                   155.920000   440.030000
# f_20107_20110_code11_QUANT_Parkinson_s_disease_...    0.737680     3.365049
# f_21003_0_0_f_QUANT_Age_when_attended_assessmen...    0.728231     3.502220
# f_30010_0_0_f_QUANT_Red_blood_cell_erythrocyte_...    4.774000     5.971000
# f_30020_0_0_f_QUANT_Haemoglobin_concentration        15.000000    19.000000
# f_30020_0_0_f_QUANT_Haemoglobin_concentration_r...    0.706956     3.621709
# f_30030_0_0_f_QUANT_Haematocrit_percentage           43.400000    54.600000
# f_30030_0_0_f_QUANT_Haematocrit_percentage_resi...    0.747491     3.538496
# f_30040_0_0_f_QUANT_Mean_corpuscular_volume          93.910000   132.700000
# f_30050_0_0_f_QUANT_Mean_corpuscular_haemoglobin     32.500000    87.510000
# f_30060_0_0_f_QUANT_Mean_corpuscular_haemoglobi...   35.090000    87.640000
# f_30070_0_0_f_QUANT_Red_blood_cell_erythrocyte_...   13.900000    28.450000
# f_30080_0_0_f_QUANT_Platelet_count                  296.500000  1215.000000
# f_30090_0_0_f_QUANT_Platelet_crit                     0.268000     1.206000
# f_30110_0_0_f_QUANT_Platelet_distribution_width      16.750000    19.240000
# f_30200_0_0_f_QUANT_Neutrophill_percentage           66.900000    92.300000
# f_30260_0_0_f_QUANT_Mean_reticulocyte_volume        110.410000   162.590000
# f_30270_0_0_f_QUANT_Mean_sphered_cell_volume         85.927500   128.880000
# f_47_f_QUANT_grip_strength_maximumValue              40.000000    80.000000
# f_50_0_0_f_QUANT_Standing_height                    175.000000   201.700000
# specialRequest_QUANT_FEV1_pred                        3.383824     4.523667
# specialRequest_QUANT_age_stopped_smoking             54.000000    70.000000
# specialRequest_QUANT_pack_years                      34.500000   198.000000

# %%
for i in range(0,len(top_correlated_df)):
    #print(i)
    boxplot=asthma_df_correlated.boxplot(column=[top_correlated_df['Feature 1'][i],top_correlated_df['Feature 2'][i]],rot=90)
    scatterplot=asthma_df_correlated.plot.scatter(x=top_correlated_df['Feature 1'][i],y=top_correlated_df['Feature 2'][i])
    plt.show(boxplot)
    boxplot.get_figure().savefig('boxplot_correlated_'+str(top_correlated_df['Correlated Rank'][i])+'.png',bbox_inches='tight')
    plt.show(scatterplot)
    scatterplot.get_figure().savefig('scatterplot_correlated_'+str(top_correlated_df['Correlated Rank'][i])+'.png',bbox_inches='tight')
